# %%
# %matplotlib inline
from matplotlib import pyplot as plt
from PIL import Image
import numpy as np
import pandas as pd
import os 
import cv2
import re, random
from tqdm import tqdm_notebook
from random import shuffle
import shutil


# %matplotlib inline

# %%
#https://www.kaggle.com/sarvajna/dogs-vs-cats-keras-solution
#https://www.kaggle.com/deadskull7/cats-vs-dogs-84

# %%
# !pip install keras-tqdm
import keras
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from keras_tqdm import TQDMNotebookCallback
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.constraints import maxnorm
from keras.optimizers import SGD
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.utils import np_utils
from keras.callbacks import Callback

from sklearn.model_selection import train_test_split

from keras.preprocessing.image import img_to_array, load_img
from keras import layers, models, optimizers
from keras import backend as K
from sklearn.model_selection import train_test_split

from sklearn.metrics import confusion_matrix
import itertools

import matplotlib.image as mpimg
import seaborn as sns
# Out:
# Collecting keras-tqdm
#   Downloading https://files.pythonhosted.org/packages/16/5c/ac63c65b79a895b8994474de2ad4d5b66ac0796b8903d60cfea3f8308d5c/keras_tqdm-2.0.1-py2.py3-none-any.whl
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from keras-tqdm) (4.28.1)
# Requirement already satisfied: Keras in /usr/local/lib/python3.6/dist-packages (from keras-tqdm) (2.2.4)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from Keras->keras-tqdm) (1.14.6)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from Keras->keras-tqdm) (1.1.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from Keras->keras-tqdm) (3.13)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from Keras->keras-tqdm) (1.0.6)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from Keras->keras-tqdm) (1.0.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from Keras->keras-tqdm) (1.11.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from Keras->keras-tqdm) (2.8.0)
# Installing collected packages: keras-tqdm
# Successfully installed keras-tqdm-2.0.1
# Using TensorFlow backend.

# %%
data_directory = '/tmp'
model_directory = '/afs/dogscats/run1'

if not os.path.isdir(model_directory):
    os.makedirs(model_directory)

# %%
def get_data(local_data_root: str, is_chief: bool=True):
    data_dir = os.path.join(local_data_root, 'datasets/dogscats')
    
    if is_chief:
        if not os.path.isdir(data_dir):
            # Download the data zip to our data directory and extract
            fallback_url = 'http://files.fast.ai/data/dogscats.zip'
            tf.keras.utils.get_file(
                os.path.join('/tmp', os.path.basename(fallback_url)), 
                fallback_url, 
                cache_dir='/tmp',
                extract=True)
        
    return data_dir

# %%
data_dir = get_data(data_directory, True)
# Out:
# Downloading data from http://files.fast.ai/data/dogscats.zip
# 857219072/857214334 [==============================] - 21s 0us/step

# %%
def organize_datasets(path_to_data, n=4000, ratio=0.2):
    files = os.listdir(path_to_data)
    files = [os.path.join(path_to_data, f) for f in files]
    shuffle(files)
    files = files[:n]
    
    n = int(len(files) * ratio)
    val, train = files[:n], files[n:]
    

    shutil.rmtree('./data/')
    print('/data/ removed')

    for c in ['dogs', 'cats']: 
        os.makedirs('./data/train/{0}/'.format(c))
        os.makedirs('./data/validation/{0}/'.format(c))

    print('folders created !')

    for t in tqdm_notebook(train):
        if 'cat' in t:
            shutil.copy2(t, os.path.join('.', 'data', 'train', 'cats'))
        else:
            shutil.copy2(t, os.path.join('.', 'data', 'train', 'dogs'))
     
    for v in tqdm_notebook(val):
        if 'cat' in v:
            shutil.copy2(v, os.path.join('.', 'data', 'validation', 'cats'))
        else:
            shutil.copy2(v, os.path.join('.', 'data', 'validation', 'dogs'))
            
    print('Data copied!')

# %%
batch_size = 32
train_datagen = ImageDataGenerator(rescale=1/255.,
                                    shear_range=0.2,
                                    zoom_range=0.2,
                                    horizontal_flip=True
                                    )
val_datagen = ImageDataGenerator(rescale=1/255.)

# %%
os.listdir(data_dir)
# Out:
# ['test1', 'train', 'valid', 'sample', 'models']

# %%
os.listdir(os.path.join(data_dir, 'valid'))
# Out:
# ['cats', 'dogs']

# %%
cats = os.listdir(os.path.join(data_dir, 'valid', 'cats'))
cats[0:3]
# Out:
# ['cat.2950.jpg', 'cat.11699.jpg', 'cat.1116.jpg']

# %%
img = plt.imread(os.path.join(data_dir, 'valid', 'cats', cats[250]))
plt.axis("off")
plt.imshow(img)

# %%
img.shape
# Out:
# (500, 477, 3)

# %%
dogs = os.listdir(os.path.join(data_dir, 'valid', 'dogs'))
dogs[0:3]
# Out:
# ['dog.6109.jpg', 'dog.532.jpg', 'dog.36.jpg']

# %%
img = plt.imread(os.path.join(data_dir, 'valid', 'dogs', dogs[0]))
plt.axis("off")
plt.imshow(img)

# %%
print(len(dogs))
# Out:
# 1000

# %%
x = [] # images as arrays
y = [] # labels
img_width = 32
img_height = 32
k=-1

for i in range(2000):
  
  if(i%2==0):
    k=k+1
    path = os.path.join(data_dir, 'valid', 'dogs', dogs[k])
    #img = cv2.imread(path,cv2.IMREAD_GRAYSCALE)
    img = cv2.imread(path) 
    img = cv2.resize(img, (img_width,img_height), interpolation=cv2.INTER_CUBIC)    
    #x.append([np.array(img)])
    x.append(img)
    y.append(1)

  else:
    path = os.path.join(data_dir, 'valid', 'cats', cats[k])
    #img = cv2.imread(path,cv2.IMREAD_GRAYSCALE)
    img = cv2.imread(path) 
    img = cv2.resize(img, (img_width,img_height), interpolation=cv2.INTER_CUBIC)
    #x.append([np.array(img)])
    x.append(img)
    y.append(0)

    
#print(len(y))
#print(y)  
#print(x)

# %%
# First split the data in two sets, 80% for training, 20% for Val/Test)
X_train, X_val, Y_train, Y_val = train_test_split(x,y, test_size=0.05, random_state=1)

# %%
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), input_shape=(img_width, img_height, 3)))
model.add(layers.Activation('relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))

model.add(layers.Conv2D(32, (3, 3)))
model.add(layers.Activation('relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))

model.add(layers.Conv2D(64, (3, 3)))
model.add(layers.Activation('relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))

model.add(layers.Flatten())
model.add(layers.Dense(64))
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1))
model.add(layers.Activation('sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        896
# _________________________________________________________________
# activation_1 (Activation)    (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 13, 13, 32)        9248
# _________________________________________________________________
# activation_2 (Activation)    (None, 13, 13, 32)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 64)          18496
# _________________________________________________________________
# activation_3 (Activation)    (None, 4, 4, 64)          0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# activation_4 (Activation)    (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# _________________________________________________________________
# activation_5 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 45,153
# Trainable params: 45,153
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

val_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

# %%
train_generator = train_datagen.flow(np.array(X_train), Y_train, batch_size=batch_size)
validation_generator = val_datagen.flow(np.array(X_val), Y_val, batch_size=batch_size)

# %%
nb_train_samples = len(X_train)
nb_validation_samples = len(X_val)
batch_size = 16

# %%
print(len(Y_val))
print(len(X_train))
# Out:
# 100
# 1900

# %%
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

val_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

# %%
train_generator = train_datagen.flow(np.array(X_train), Y_train, batch_size=batch_size)
validation_generator = val_datagen.flow(np.array(X_val), Y_val, batch_size=batch_size)

# %%
history = model.fit_generator(
    train_generator, 
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=100,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size
)
# Out:
# Epoch 1/100
# 118/118 [==============================] - 4s 38ms/step - loss: 0.6996 - acc: 0.4873 - val_loss: 0.6818 - val_acc: 0.5625
# Epoch 2/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.6944 - acc: 0.5065 - val_loss: 0.6895 - val_acc: 0.6190
# Epoch 3/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.6885 - acc: 0.5503 - val_loss: 0.6767 - val_acc: 0.5595
# Epoch 4/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.6784 - acc: 0.5697 - val_loss: 0.6498 - val_acc: 0.6310
# Epoch 5/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.6682 - acc: 0.5839 - val_loss: 0.6281 - val_acc: 0.7024
# Epoch 6/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.6557 - acc: 0.6153 - val_loss: 0.6738 - val_acc: 0.5238
# Epoch 7/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.6397 - acc: 0.6345 - val_loss: 0.6355 - val_acc: 0.6786
# Epoch 8/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.6297 - acc: 0.6531 - val_loss: 0.6099 - val_acc: 0.6562
# Epoch 9/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.6279 - acc: 0.6492 - val_loss: 0.6899 - val_acc: 0.6071
# Epoch 10/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.6194 - acc: 0.6716 - val_loss: 0.6367 - val_acc: 0.6786
# Epoch 11/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.6120 - acc: 0.6794 - val_loss: 0.6734 - val_acc: 0.6310
# Epoch 12/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.5924 - acc: 0.6912 - val_loss: 0.5976 - val_acc: 0.7024
# Epoch 13/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.5877 - acc: 0.6836 - val_loss: 0.7336 - val_acc: 0.5833
# Epoch 14/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.5837 - acc: 0.6811 - val_loss: 0.6454 - val_acc: 0.6429
# Epoch 15/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.5565 - acc: 0.7228 - val_loss: 0.5853 - val_acc: 0.7396
# Epoch 16/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.5679 - acc: 0.7025 - val_loss: 0.6479 - val_acc: 0.6667
# Epoch 17/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.5513 - acc: 0.7258 - val_loss: 0.6116 - val_acc: 0.6310
# Epoch 18/100
# 118/118 [==============================] - 4s 32ms/step - loss: 0.5413 - acc: 0.7318 - val_loss: 0.8027 - val_acc: 0.4643
# Epoch 19/100
# 118/118 [==============================] - 4s 32ms/step - loss: 0.5257 - acc: 0.7260 - val_loss: 0.5312 - val_acc: 0.7500
# Epoch 20/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.5282 - acc: 0.7435 - val_loss: 0.6884 - val_acc: 0.6667
# Epoch 21/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.5257 - acc: 0.7511 - val_loss: 0.5504 - val_acc: 0.7262
# Epoch 22/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.5092 - acc: 0.7608 - val_loss: 0.5389 - val_acc: 0.7500
# Epoch 23/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.4955 - acc: 0.7486 - val_loss: 0.5815 - val_acc: 0.7024
# Epoch 24/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.5059 - acc: 0.7463 - val_loss: 0.7298 - val_acc: 0.6071
# Epoch 25/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.4838 - acc: 0.7712 - val_loss: 0.7317 - val_acc: 0.6548
# Epoch 26/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.5079 - acc: 0.7544 - val_loss: 0.4937 - val_acc: 0.7024
# Epoch 27/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.4787 - acc: 0.7754 - val_loss: 0.6732 - val_acc: 0.6429
# Epoch 28/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.4914 - acc: 0.7694 - val_loss: 0.5948 - val_acc: 0.6786
# Epoch 29/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.4703 - acc: 0.7835 - val_loss: 0.6727 - val_acc: 0.6458
# Epoch 30/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.4703 - acc: 0.7583 - val_loss: 0.6915 - val_acc: 0.6667
# Epoch 31/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.4528 - acc: 0.7934 - val_loss: 0.6361 - val_acc: 0.7262
# Epoch 32/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.4686 - acc: 0.7754 - val_loss: 0.5921 - val_acc: 0.7143
# Epoch 33/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.4419 - acc: 0.7906 - val_loss: 0.6675 - val_acc: 0.6429
# Epoch 34/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.4685 - acc: 0.7703 - val_loss: 0.6732 - val_acc: 0.6548
# Epoch 35/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.4417 - acc: 0.8097 - val_loss: 0.5860 - val_acc: 0.7381
# Epoch 36/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.4255 - acc: 0.7917 - val_loss: 0.6229 - val_acc: 0.7188
# Epoch 37/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.4205 - acc: 0.7984 - val_loss: 0.6804 - val_acc: 0.7262
# Epoch 38/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.4505 - acc: 0.7924 - val_loss: 0.6563 - val_acc: 0.7024
# Epoch 39/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.4389 - acc: 0.8023 - val_loss: 0.7175 - val_acc: 0.7381
# Epoch 40/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.4219 - acc: 0.8114 - val_loss: 0.4679 - val_acc: 0.7619
# Epoch 41/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.4137 - acc: 0.8166 - val_loss: 0.8222 - val_acc: 0.6429
# Epoch 42/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.4020 - acc: 0.8157 - val_loss: 0.7716 - val_acc: 0.7143
# Epoch 43/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.3985 - acc: 0.8252 - val_loss: 0.5256 - val_acc: 0.7292
# Epoch 44/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.4097 - acc: 0.8143 - val_loss: 0.8234 - val_acc: 0.6548
# Epoch 45/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.3955 - acc: 0.8259 - val_loss: 0.6229 - val_acc: 0.7024
# Epoch 46/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.3916 - acc: 0.8259 - val_loss: 0.5363 - val_acc: 0.7381
# Epoch 47/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.3882 - acc: 0.8241 - val_loss: 0.6432 - val_acc: 0.6905
# Epoch 48/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.3874 - acc: 0.8257 - val_loss: 0.8229 - val_acc: 0.6786
# Epoch 49/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.3774 - acc: 0.8404 - val_loss: 0.7729 - val_acc: 0.6905
# Epoch 50/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.3786 - acc: 0.8236 - val_loss: 0.7726 - val_acc: 0.6458
# Epoch 51/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.3574 - acc: 0.8388 - val_loss: 0.6451 - val_acc: 0.7381
# Epoch 52/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.3468 - acc: 0.8490 - val_loss: 1.0329 - val_acc: 0.6905
# Epoch 53/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.3679 - acc: 0.8480 - val_loss: 0.7060 - val_acc: 0.7143
# Epoch 54/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.3588 - acc: 0.8400 - val_loss: 0.7575 - val_acc: 0.7143
# Epoch 55/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.3486 - acc: 0.8386 - val_loss: 0.5205 - val_acc: 0.7262
# Epoch 56/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.3793 - acc: 0.8249 - val_loss: 0.7345 - val_acc: 0.7143
# Epoch 57/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.3336 - acc: 0.8540 - val_loss: 0.9873 - val_acc: 0.6771
# Epoch 58/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.3502 - acc: 0.8469 - val_loss: 0.5404 - val_acc: 0.7381
# Epoch 59/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.3560 - acc: 0.8492 - val_loss: 0.8014 - val_acc: 0.6905
# Epoch 60/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.3450 - acc: 0.8496 - val_loss: 0.7582 - val_acc: 0.6786
# Epoch 61/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.3365 - acc: 0.8480 - val_loss: 0.8660 - val_acc: 0.7262
# Epoch 62/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.3474 - acc: 0.8494 - val_loss: 0.9136 - val_acc: 0.6310
# Epoch 63/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.3447 - acc: 0.8471 - val_loss: 0.5650 - val_acc: 0.7619
# Epoch 64/100
# 118/118 [==============================] - 4s 32ms/step - loss: 0.3358 - acc: 0.8653 - val_loss: 0.9118 - val_acc: 0.7188
# Epoch 65/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.3345 - acc: 0.8552 - val_loss: 1.0552 - val_acc: 0.6905
# Epoch 66/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.3274 - acc: 0.8607 - val_loss: 0.6097 - val_acc: 0.7262
# Epoch 67/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.3187 - acc: 0.8533 - val_loss: 0.6339 - val_acc: 0.7500
# Epoch 68/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.3203 - acc: 0.8701 - val_loss: 0.8158 - val_acc: 0.6190
# Epoch 69/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.3050 - acc: 0.8694 - val_loss: 1.1190 - val_acc: 0.6429
# Epoch 70/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.3260 - acc: 0.8690 - val_loss: 0.7663 - val_acc: 0.7381
# Epoch 71/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.2830 - acc: 0.8831 - val_loss: 0.7541 - val_acc: 0.7292
# Epoch 72/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.3063 - acc: 0.8637 - val_loss: 0.8808 - val_acc: 0.6786
# Epoch 73/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.3012 - acc: 0.8688 - val_loss: 0.7543 - val_acc: 0.7976
# Epoch 74/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.2896 - acc: 0.8754 - val_loss: 1.0531 - val_acc: 0.7143
# Epoch 75/100
# 118/118 [==============================] - 4s 30ms/step - loss: 0.3150 - acc: 0.8672 - val_loss: 0.7508 - val_acc: 0.6905
# Epoch 76/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.3139 - acc: 0.8699 - val_loss: 0.8465 - val_acc: 0.6786
# Epoch 77/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.2994 - acc: 0.8641 - val_loss: 0.7650 - val_acc: 0.7738
# Epoch 78/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.2972 - acc: 0.8796 - val_loss: 0.9557 - val_acc: 0.7188
# Epoch 79/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.3006 - acc: 0.8679 - val_loss: 1.0829 - val_acc: 0.6905
# Epoch 80/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.3042 - acc: 0.8789 - val_loss: 0.9006 - val_acc: 0.7857
# Epoch 81/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.3055 - acc: 0.8732 - val_loss: 0.9462 - val_acc: 0.6429
# Epoch 82/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.3086 - acc: 0.8639 - val_loss: 0.8484 - val_acc: 0.7262
# Epoch 83/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.3137 - acc: 0.8768 - val_loss: 0.8760 - val_acc: 0.7381
# Epoch 84/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.2802 - acc: 0.8849 - val_loss: 0.8310 - val_acc: 0.7024
# Epoch 85/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.2917 - acc: 0.8849 - val_loss: 1.3133 - val_acc: 0.7188
# Epoch 86/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.2927 - acc: 0.8879 - val_loss: 1.0955 - val_acc: 0.7381
# Epoch 87/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.2964 - acc: 0.8806 - val_loss: 0.9215 - val_acc: 0.6310
# Epoch 88/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.2624 - acc: 0.8930 - val_loss: 1.0023 - val_acc: 0.6786
# Epoch 89/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.2948 - acc: 0.8764 - val_loss: 0.8534 - val_acc: 0.7262
# Epoch 90/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.2978 - acc: 0.8819 - val_loss: 0.8101 - val_acc: 0.7024
# Epoch 91/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.2752 - acc: 0.8794 - val_loss: 1.2286 - val_acc: 0.6310
# Epoch 92/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.2768 - acc: 0.8792 - val_loss: 0.9603 - val_acc: 0.6875
# Epoch 93/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.2810 - acc: 0.8792 - val_loss: 0.8621 - val_acc: 0.7262
# Epoch 94/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.2798 - acc: 0.8902 - val_loss: 0.6786 - val_acc: 0.7738
# Epoch 95/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.2999 - acc: 0.8776 - val_loss: 0.9234 - val_acc: 0.6667
# Epoch 96/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.2782 - acc: 0.8863 - val_loss: 1.5253 - val_acc: 0.7143
# Epoch 97/100
# 118/118 [==============================] - 4s 31ms/step - loss: 0.2902 - acc: 0.8882 - val_loss: 0.7941 - val_acc: 0.7143
# Epoch 98/100
# 118/118 [==============================] - 4s 32ms/step - loss: 0.2608 - acc: 0.8955 - val_loss: 1.2811 - val_acc: 0.7500
# Epoch 99/100
# 118/118 [==============================] - 4s 32ms/step - loss: 0.3015 - acc: 0.8803 - val_loss: 1.2155 - val_acc: 0.6667
# Epoch 100/100
# 118/118 [==============================] - 4s 32ms/step - loss: 0.2754 - acc: 0.8847 - val_loss: 1.1300 - val_acc: 0.6548
