# %%
# !git clone https://github.com/rodolfojbrandao/PhD/
# Out:
# Cloning into 'PhD'...
# remote: Counting objects: 22, done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 22 (delta 7), reused 16 (delta 4), pack-reused 0
# Unpacking objects: 100% (22/22), done.

# %%
% cd PhD
! ls
# Out:
# /content/PhD
# dados.csv	GPU.py		       mixingindex.py	README.md
# data-filter.py	liggghts-variables.py  optimization.py

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
DAT = pd.read_csv('dados.csv')
print(DAT.head())
# Out:
#    Unnamed: 0  type       v:0       v:1       v:2  radius  Points:0  Points:1  \
# 0           0     1  0.066329 -0.029380  0.000091  0.0021 -0.029423 -0.066345
# 1           1     1  0.068571 -0.023945 -0.000013  0.0021 -0.023987 -0.068577
# 2           2     1  0.068949 -0.023041 -0.000009  0.0021 -0.023091 -0.068945
# 3           3     1  0.069952 -0.020214 -0.000036  0.0021 -0.020211 -0.069956
# 4           4     1  0.066273 -0.020539  0.000053  0.0021 -0.020707 -0.066332
#
#    Points:2
# 0  0.003761
# 1  0.003303
# 2  0.007845
# 3  0.002099
# 4  0.005093

# %%
row = DAT.shape[0]
print(f'o numero de linhas eh {row}')
col = DAT.shape[1]
print(f'o numero de colunas eh {col}')
# Out:
# o numero de linhas eh 21522
# o numero de colunas eh 9

# %%
print(DAT.iloc[10,2])
# Out:
# 0.067719

# %%
velocidade_resultante=np.zeros(row)
#M.iloc[:,[i]]=M.iloc[:,[i]].apply(lambda x:(x-a)/b)
for i in range(row):
  velocidade_resultante[i]=DAT.iloc[i,2]*DAT.iloc[i,2]+DAT.iloc[i,3]*DAT.iloc[i,3]+DAT.iloc[i,4]*DAT.iloc[i,4]
print(velocidade_resultante)
print(len(velocidade_resultante))
# Out:
# [0.00526273 0.00527535 0.00528485 ... 0.0053009  0.00479987 0.00527775]
# 21522

# %%
#Carvao_novo = Carvao[['Water', 'Ash', 'Volatil']].copy()
posicaoX = DAT.iloc[:,2].copy()
print(posicaoX)
# Out:
# 0        0.066329
# 1        0.068571
# 2        0.068949
# 3        0.069952
# 4        0.066273
# 5        0.070116
# 6        0.069392
# 7        0.070907
# 8        0.066641
# 9        0.071508
# 10       0.067719
# 11       0.067356
# 12       0.071708
# 13       0.072323
# 14       0.068627
# 15       0.072502
# 16       0.068181
# 17       0.068921
# 18       0.071332
# 19       0.072546
# 20       0.066653
# 21       0.069219
# 22       0.065919
# 23       0.072546
# 24       0.072525
# 25       0.069323
# 26       0.068334
# 27       0.072540
# 28       0.072535
# 29       0.069448
#            ...
# 21492    0.040354
# 21493    0.037249
# 21494    0.037653
# 21495    0.042752
# 21496    0.041595
# 21497    0.041125
# 21498    0.037848
# 21499    0.039611
# 21500    0.040702
# 21501    0.036774
# 21502    0.040717
# 21503    0.040664
# 21504    0.035247
# 21505    0.038548
# 21506    0.042035
# 21507    0.040251
# 21508    0.038599
# 21509    0.036887
# 21510    0.035834
# ...
