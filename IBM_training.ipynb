# %%
name="Lizz"
print(name[0:2])
# Out:
# Li

# %%
L = [0]

# %%
L.append(['a','b'])
print(L)
# Out:
# [0, ['a', 'b']]

# %%
var = '01234567'
print(var[::2])
# Out:
# 0246

# %%
'1'+'2'
# Out:
# '12'

# %%
A=range(0,3)
print(A)
# Out:
# range(0, 3)

# %%
def f1(a):
  b = a + 1
  return b

f1(8)
# Out:
# 9

# %%
A=['1','2','3']

for a in A:

  print(2*a)
# Out:
# 11
# 22
# 33

# %%
import pandas as pd
df=pd.DataFrame({'a':[1,2,1],'b':[1,1,1]})
df['a']==1
# Out:
# 0     True
# 1    False
# 2     True
# Name: a, dtype: bool

# %%
import numpy as np
np.array([1,-1])*np.array([1,1])
np.dot(np.array([1,-1]),np.array([1,1]))
# Out:
# 0

# %%
A=np.array([[1,2],[3,4],[5,6],[7,8]])
print(A)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]
#  [7 8]]

# %%
a=np.array([1,1,1,1,1])

a+10
# Out:
# array([11, 11, 11, 11, 11])

# %%
Name="Michael Jackson"
Name.find('el')
# Out:
# 5

# %%
for n in range(0,3):
  print(n+1)
# Out:
# 1
# 2
# 3

# %%
class Points(object):

  def __init__(self,x,y):

    self.x=x

    self.y=y

  def print_point(self):

    print('x=',self.x,' y=',self.y)

p2=Points(1,2)

p2.x=2

p2.print_point()
# Out:
# x= 2  y= 2

# %%
import numpy as np
import pandas as pd
import math
import matplotlib
import matplotlib.pyplot as plt

x = np.random.randint(20, size=(1, 1000))
x=pd.DataFrame(x)
print(x)
plt.title("histograma")
plt.ylabel("y")
plt.xlabel("x")
plt.hist(x, 20)
# Out:
#    0    1    2    3    4    5    6    ...  993  994  995  996  997  998  999
# 0   10    9    3   10    2   18    8  ...    8   17   12   15    3    3   11
#
# [1 rows x 1000 columns]
# (array([53., 43., 48., 54., 47., 55., 53., 56., 57., 62., 35., 43., 43.,
#         53., 42., 51., 56., 41., 59., 49.]),
#  array([ 0.  ,  0.95,  1.9 ,  2.85,  3.8 ,  4.75,  5.7 ,  6.65,  7.6 ,
#          8.55,  9.5 , 10.45, 11.4 , 12.35, 13.3 , 14.25, 15.2 , 16.15,
#         17.1 , 18.05, 19.  ]),
#  <a list of 20 Patch objects>)

# %%
import numpy as np
import pandas as pd
import math
import matplotlib
import matplotlib.pyplot as plt

series_data = np.random.randint(20, size=(1, 50))
series_data=pd.DataFrame(series_data)

count, bin_edges = np.histogram(series_data)
series_data.plot(kind='hist', xticks = bin_edges)

# %%
import numpy as np
import pandas as pd
import math
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn as sns

ax = sns.regplot(x="year", y="total", data=data_dataframe, color="green", marker="+")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-0262ac4fd258> in <module>()
#       9 y=np.random.randint(20, size=(1, 50))
#      10
# ---> 11 ax = sns.regplot(x='x',y='y')
#
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     779                                  order, logistic, lowess, robust, logx,
#     780                                  x_partial, y_partial, truncate, dropna,
# --> 781                                  x_jitter, y_jitter, color, label)
#     782
#     783     if ax is None:
#
# ...

# %%
import folium
world_map=folium.Map(location=[-12.2536, -38.9601],zoom_start=15, tiles='Stamen Terrain')
world_map
#spain=folium.Map(location=[40.4637, 3.7492], zoom_start=6, tiles='Stamen Toner')
#spain
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
